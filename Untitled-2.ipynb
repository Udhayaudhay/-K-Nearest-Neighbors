# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
diabetes_df=pd.read_csv("C:/Users/udhay/Downloads/dataset/diabetes (1).csv")

# %%
type(diabetes_df)
# Out:
# pandas.core.frame.DataFrame

# %%
diabetes_df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
diabetes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
diabetes_df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
diabetes_df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
diabetes_df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
diabetes_df[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin','BMI']]=diabetes_df[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin','BMI']].replace(0,np.nan)

# %%
diabetes_df.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
diabetes_df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0      NaN  33.6
# 1              1     85.0           66.0           29.0      NaN  26.6
# 2              8    183.0           64.0            NaN      NaN  23.3
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0           48.0    180.0  32.9
# 764            2    122.0           70.0           27.0      NaN  36.8
# 765            5    121.0           72.0           23.0    112.0  26.2
# 766            1    126.0           60.0            NaN      NaN  30.1
# 767            1     93.0           70.0           31.0      NaN  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
diabetes_df.hist(figsize= (10,15))
# Out:
# array([[<Axes: title={'center': 'Pregnancies'}>,
#         <Axes: title={'center': 'Glucose'}>,
#         <Axes: title={'center': 'BloodPressure'}>],
#        [<Axes: title={'center': 'SkinThickness'}>,
#         <Axes: title={'center': 'Insulin'}>,
#         <Axes: title={'center': 'BMI'}>],
#        [<Axes: title={'center': 'DiabetesPedigreeFunction'}>,
#         <Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Outcome'}>]], dtype=object)

# %%
sns.pairplot(diabetes_df)

# %%
sns.heatmap(diabetes_df.corr(),annot=True)
# Out:
# <Axes: >

# %%
pip install scikit-learn
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# ...
#    ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#    ------- -------------------------------- 1.6/8.9 MB 12.0 MB/s eta 0:00:01
#    ------------------ --------------------- 4.2/8.9 MB 10.1 MB/s eta 0:00:01
#    ------------------------------- -------- 7.1/8.9 MB 11.5 MB/s eta 0:00:01
#    ------------------------------------ --- 8.1/8.9 MB 9.7 MB/s eta 0:00:01
#    ---------------------------------------- 8.9/8.9 MB 9.1 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/38.7 MB ? eta -:--:--
#    - -------------------------------------- 1.8/38.7 MB 8.4 MB/s eta 0:00:05
#    --- ------------------------------------ 3.7/38.7 MB 8.7 MB/s eta 0:00:05
#    ----- ---------------------------------- 5.8/38.7 MB 9.0 MB/s eta 0:00:04
#    -------- ------------------------------- 8.1/38.7 MB 9.5 MB/s eta 0:00:04
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x=diabetes_df[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age', ]]

# %%
x
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0      NaN  33.6
# 1              1     85.0           66.0           29.0      NaN  26.6
# 2              8    183.0           64.0            NaN      NaN  23.3
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0           48.0    180.0  32.9
# 764            2    122.0           70.0           27.0      NaN  36.8
# 765            5    121.0           72.0           23.0    112.0  26.2
# 766            1    126.0           60.0            NaN      NaN  30.1
# 767            1     93.0           70.0           31.0      NaN  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
y=diabetes_df["Outcome"]

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
x_train,x_test,y_train,y_test =  train_test_split(x,y,test_size=0.33,random_state=42)

# %%
x_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 464           10    115.0           98.0            NaN      NaN  24.0
# 223            7    142.0           60.0           33.0    190.0  28.8
# 393            4    116.0           72.0           12.0     87.0  22.1
# 766            1    126.0           60.0            NaN      NaN  30.1
# 570            3     78.0           70.0            NaN      NaN  32.5
# ..           ...      ...            ...            ...      ...   ...
# 71             5    139.0           64.0           35.0    140.0  28.6
# 106            1     96.0          122.0            NaN      NaN  22.4
# 270           10    101.0           86.0           37.0      NaN  45.6
# 435            0    141.0            NaN            NaN      NaN  42.4
# 102            0    125.0           96.0            NaN      NaN  22.5
#
#      DiabetesPedigreeFunction  Age
# 464                     1.022   34
# 223                     0.687   61
# ...

# %%
x_test
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 668            6     98.0           58.0           33.0    190.0  34.0
# 324            2    112.0           75.0           32.0      NaN  35.7
# 624            2    108.0           64.0            NaN      NaN  30.8
# 690            8    107.0           80.0            NaN      NaN  24.6
# 473            7    136.0           90.0            NaN      NaN  29.9
# ..           ...      ...            ...            ...      ...   ...
# 311            0    106.0           70.0           37.0    148.0  39.4
# 429            1     95.0           82.0           25.0    180.0  35.0
# 182            1      NaN           74.0           20.0     23.0  27.7
# 586            8    143.0           66.0            NaN      NaN  34.9
# 679            2    101.0           58.0           17.0    265.0  24.2
#
#      DiabetesPedigreeFunction  Age
# 668                     0.430   43
# 324                     0.148   21
# ...

# %%
x_train.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       4
# BloodPressure                18
# SkinThickness               146
# Insulin                     251
# BMI                           5
# DiabetesPedigreeFunction      0
# Age                           0
# dtype: int64

# %%
x_test.isnull(). sum()
# Out:
# Pregnancies                   0
# Glucose                       1
# BloodPressure                17
# SkinThickness                81
# Insulin                     123
# BMI                           6
# DiabetesPedigreeFunction      0
# Age                           0
# dtype: int64

# %%
columns_with_nan=["Glucose","BloodPressure","SkinThickness","Insulin","BMI"]
fig,ax=plt.subplots(nrows=1,ncols=5,figsize=(20,5))
for i in range(len(columns_with_nan)):
    sns.distplot(x_train[columns_with_nan[i]],ax=ax[i])
# Out:
# C:\Users\udhay\AppData\Local\Temp\ipykernel_14508\1688798143.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x_train[columns_with_nan[i]],ax=ax[i])
# C:\Users\udhay\AppData\Local\Temp\ipykernel_14508\1688798143.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
Glucose_meaan_xtrain=x_train.loc[:,"Glucose"].mean()
Glucose_meaan_xtrain
# Out:
# np.float64(122.24705882352941)

# %%
BloodPressure_meaan_xtrain=x_train.loc[:,"BloodPressure"].mean()
BloodPressure_meaan_xtrain
# Out:
# np.float64(72.5241935483871)

# %%
SkinThickness_median_xtrain=x_train.loc[:,"SkinThickness"].median()
Insulin_median_xtrain=x_train.loc[:,"Insulin"].median()
BMI_median_xtrain=x_train.loc[:,"BMI"].median()

# %%
BMI_median_xtrain
# Out:
# np.float64(32.0)

# %%
x_train.loc[:,"Glucose"]=x_train.loc[:,"Glucose"].fillna(Glucose_meaan_xtrain)
x_train.loc[:,"BloodPressure"]=x_train.loc[:,"BloodPressure"].fillna(BloodPressure_meaan_xtrain)
x_train.loc[:,"SkinThickness"]=x_train.loc[:,"SkinThickness"].fillna(SkinThickness_median_xtrain)
x_train.loc[:,"Insulin"]=x_train.loc[:,"Insulin"].fillna(Insulin_median_xtrain)
x_train.loc[:,"BMI"]=x_train.loc[:,"BMI"].fillna(BMI_median_xtrain)

# %%
x_train.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# dtype: int64

# %%
x_test.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       1
# BloodPressure                17
# SkinThickness                81
# Insulin                     123
# BMI                           6
# DiabetesPedigreeFunction      0
# Age                           0
# dtype: int64

# %%
x_test.loc[:,"Glucose"]=x_test.loc[:,"Glucose"].fillna(Glucose_meaan_xtrain)
x_test.loc[:,"BloodPressure"]=x_test.loc[:,"BloodPressure"].fillna(BloodPressure_meaan_xtrain)
x_test.loc[:,"SkinThickness"]=x_test.loc[:,"SkinThickness"].fillna(SkinThickness_median_xtrain)
x_test.loc[:,"Insulin"]=x_test.loc[:,"Insulin"].fillna(Insulin_median_xtrain)
x_test.loc[:,"BMI"]=x_test.loc[:,"BMI"].fillna(BMI_median_xtrain)

# %%
x_test.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# dtype: int64

# %%
x_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 464           10    115.0      98.000000           29.0    125.0  24.0
# 223            7    142.0      60.000000           33.0    190.0  28.8
# 393            4    116.0      72.000000           12.0     87.0  22.1
# 766            1    126.0      60.000000           29.0    125.0  30.1
# 570            3     78.0      70.000000           29.0    125.0  32.5
# ..           ...      ...            ...            ...      ...   ...
# 71             5    139.0      64.000000           35.0    140.0  28.6
# 106            1     96.0     122.000000           29.0    125.0  22.4
# 270           10    101.0      86.000000           37.0    125.0  45.6
# 435            0    141.0      72.524194           29.0    125.0  42.4
# 102            0    125.0      96.000000           29.0    125.0  22.5
#
#      DiabetesPedigreeFunction  Age
# 464                     1.022   34
# 223                     0.687   61
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
min_max_scaler=MinMaxScaler()

# %%
xtrain=min_max_scaler.fit_transform(x_train)

# %%
xtrain
# Out:
# array([[0.58823529, 0.45806452, 0.75510204, ..., 0.11860941, 0.4030743 ,
#         0.21666667],
#        [0.41176471, 0.63225806, 0.36734694, ..., 0.21676892, 0.26003416,
#         0.66666667],
#        [0.23529412, 0.46451613, 0.48979592, ..., 0.0797546 , 0.16438941,
#         0.26666667],
#        ...,
#        [0.58823529, 0.36774194, 0.63265306, ..., 0.5603272 , 0.45175064,
#         0.28333333],
#        [0.        , 0.62580645, 0.49514483, ..., 0.49488753, 0.05422716,
#         0.13333333],
#        [0.        , 0.52258065, 0.73469388, ..., 0.08793456, 0.07856533,
#         0.        ]], shape=(514, 8))

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_model=KNeighborsClassifier(10)

# %%
knn_model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
y_pred=knn_model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7165354330708661

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.83      0.80       168
#            1       0.60      0.49      0.54        86
#
#     accuracy                           0.72       254
#    macro avg       0.68      0.66      0.67       254
# weighted avg       0.71      0.72      0.71       254

# %%
knn_model.predict(np.array([[	0,	125.0,	96.000000,	122.247059	,122.247059	,22.5	,0.262	,21]]))
# Out:
# c:\Users\udhay\Downloads\data handlin pre processing\.conda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array([0])
